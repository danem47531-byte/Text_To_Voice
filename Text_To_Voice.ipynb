# %%
# !pip install gtts
# Out:
# Collecting gtts
#   Downloading gTTS-2.5.4-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\tridev pal\downloads\anacondajupiter\lib\site-packages (from gtts) (2.32.5)
# Requirement already satisfied: click<8.2,>=7.1 in c:\users\tridev pal\downloads\anacondajupiter\lib\site-packages (from gtts) (8.1.7)
# Requirement already satisfied: colorama in c:\users\tridev pal\downloads\anacondajupiter\lib\site-packages (from click<8.2,>=7.1->gtts) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\tridev pal\downloads\anacondajupiter\lib\site-packages (from requests<3,>=2.27->gtts) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tridev pal\downloads\anacondajupiter\lib\site-packages (from requests<3,>=2.27->gtts) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tridev pal\downloads\anacondajupiter\lib\site-packages (from requests<3,>=2.27->gtts) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tridev pal\downloads\anacondajupiter\lib\site-packages (from requests<3,>=2.27->gtts) (2026.1.4)
# Downloading gTTS-2.5.4-py3-none-any.whl (29 kB)
# Installing collected packages: gtts
# Successfully installed gtts-2.5.4
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Language	Code
# English	'en'
# Hindi	'hi'
# French	'fr'
# Spanish	'es'
# Bengali	'bn'

# %%
from gtts import gTTS

text = """Hi my name is Tridev Pal"""
tts = gTTS(text=text, lang='hi')
tts.save("demo_audio.mp3")

print("Audio file saved as demo_audio.mp3")
# Out:
# Audio file saved as demo_audio.mp3

# %%
from IPython.display import Audio

Audio("demo_audio.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
